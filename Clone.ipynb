# %% [markdown]
# # Clone `EarthScienceExperiment` repository
#
# https://github.com/yasuit21/EarthScienceExperiment
#
# Only to run the two cells below. If you'd like to specify the directory to clone, please modify the directory path in `os.chdir` at the second cell.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
from pathlib import Path

#@markdown Designate `target_directory` to clone the repository
target_directory = "/content/drive/MyDrive" #@param ["/content/drive/MyDrive", "/content/drive/MyDrive/Sample"] {allow-input: false}
Path(target_directory).mkdir(exist_ok=True, parents=True)
os.chdir(target_directory)
# !git clone https://github.com/yasuit21/EarthScienceExperiment.git
